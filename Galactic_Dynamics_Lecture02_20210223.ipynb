# %% [markdown]
# ##Lecture 2: Plotting the Equation of Orbit for various eccentricities

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

def init():
  ax.set_xlim(-5, 1)
  ax.set_ylim(-2, 2)
  plt.plot(0, 0, 'kx')
  ax.set_xlabel(r'$x$')
  ax.set_ylabel(r'$y$')
  return ln,

def update(frame):
  xdata.append(ell2_by_k / (1 + e * np.cos(frame)) * np.cos(frame))
  ydata.append(ell2_by_k / (1 + e * np.cos(frame)) * np.sin(frame))
  ln.set_data(xdata, ydata)
  return ln,

e = 0.75 #ellipse
#e = 1.0 #parabola
#e = 1.5 #hyperbola
ell2_by_k = 1.0 #square of the specific angular momentum divided by the gravitational parameter G(m1 + m2)
fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'r.')

#Print orbit parameters and conserved quantities
ani = FuncAnimation(fig, update, frames = np.linspace(-np.pi, np.pi, 64), init_func = init, blit = True)
HTML(ani.to_jshtml())
